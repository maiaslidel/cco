# %% [markdown]
# ## **What does this code do?**
# - Pulls data from Fingertips using a formatted and parsed URL. The parameters by which the data is pulled are fully customisable
# - Performs basic data transformation steps on the Fingertips data, such as filtering for NCL and removing undesired columns
# - Retrieves social prescribing data from raw data folder in Sharepoint (pre-downloaded and uploaded manually from email)
# - Performs data transformation steps on the social prescribing data, removing rows, creating a date column etc.
# - Merges the Fingertips and social prescribing data
# - Uploads the merged and finalised file to the production data folder in Sharepoint

# %%
import fingertips_py as ftp
import pandas as pd

# %%
# df = ftp.api_calls.deal_with_url_error("https://fingertipsws.phe.org.uk/api/all_data/csv/by_group_id?v=/0-2205ecc6/&parent_area_code=nE38000240&parent_area_type_id=66&child_area_type_id=7&group_id=1938133365&category_area_code=null")

# %% [markdown]
# ## Retrieving Fingertips Data

# %%
ftp.metadata.get_metadata(indicator_ids=None, domain_ids=None, profile_ids=92) #pulls metadata on cancer profile
# Out:
#     Indicator ID                                          Indicator  \
# 0          93468  Proportion of GP registered populations by age...
# 1          93553                       Deprivation score (IMD 2019)
# 2          91337            New cancer cases (Crude incidence rate)
# 3          94063  Breast screening coverage: aged 53 to 70 years...
# 4          93725  Cervical screening coverage: aged 25 to 49 yea...
# 5          93726  Cervical screening coverage: aged 50 to 64 yea...
# 6          92600  Bowel cancer screening coverage: aged 60 to 74...
# 7          92605  Urgent suspected cancer referrals (Indirectly ...
# 8          92608  Urgent suspected cancer referrals resulting in...
# 9          92609  New cancer cases treated resulting from an urg...
# 10           276                  Cancer: QOF prevalence (all ages)
# 11         91339  Breast screening coverage: aged 50 to 70 years...
# 12         91340   Breast screening uptake: aged 50 to 70 years old
# 13         92601  Bowel cancer screening uptake: aged 60 to 74 y...
# 14         91352      In-patient or day-case colonoscopy procedures
# 15         91353    In-patient or day-case sigmoidoscopy procedures
# 16         91354  In-patient or day-case upper GI endoscopy proc...
# 17         91355         Number of emergency admissions with cancer
# 18         91356                  Number of emergency presentations
# 19         91357      Number of other (non-emergency) presentations
# 20         91882                  Urgent suspected cancer referrals
# 21         91344  Urgent suspected cancer referrals (Indirectly ...
# 22         91845  Urgent suspected cancer referrals resulting in...
# 23         91347  New cancer cases treated resulting from an urg...
# 24         91348  Urgent suspected cancer referrals for suspecte...
# 25         91349  Urgent suspected cancer referrals for suspecte...
# 26         91350  Urgent suspected cancer referrals for suspecte...
# 27         91351  Urgent suspected cancer referrals for suspecte...
# 28         92604  Urgent suspected cancer referrals. Five years ...
# 29         92610  Urgent suspected cancer referrals for suspecte...
# 30         92611  Urgent suspected cancer referrals for suspecte...
# 31         92612  Urgent suspected cancer referrals for suspecte...
# 32         92613  Urgent suspected cancer referrals for suspecte...
#
#                                            Definition  \
# 0   Proportion of the GP registered population (in...
# 1   The English Indices of Deprivation 2019 use 39...
# 2   The number of persons diagnosed with any invas...
# 3   3-year screening coverage %: The number of eli...
# 4   3.5-year cervical screening coverage (%): the ...
# 5   5.5-year cervical screening coverage (%): the ...
# 6   2.5-year screening coverage (%): the number of...
# 7   The number of urgent suspected cancer referral...
# 8   The number of urgent suspected cancer referral...
# 9   The proportion of new cancer cases treated who...
# 10  The percentage of patients with cancer, as rec...
# 11  3-year screening coverage %: The number of per...
# 12  1-year screening uptake (%): The number of wom...
# 13  1-year screening uptake %: the number of perso...
# 14  The number of colonoscopies (in-patient and da...
# 15  The number of sigmoidoscopies (in-patient and ...
# 16  The number of endoscopies of the upper gastroi...
# 17  The crude rate per 100,000 persons of all emer...
# 18  The crude rate of persons diagnosed with cance...
# 19  The crude rate of persons diagnosed with cance...
# 20  The number of urgent suspected cancer referral...
# 21  The number of urgent suspected cancer referral...
# 22  The number of urgent suspected cancer referral...
# 23  The proportion of new cancer cases treated who...
# 24  The number of urgent suspected breast cancer r...
# 25  The number of urgent suspected lower GI cancer...
# 26  The number of urgent suspected lung cancer ref...
# 27  The number of urgent suspected skin cancer ref...
# 28  The number of urgent suspected cancer referral...
# 29  The number of urgent suspected breast cancer r...
# 30  The number of urgent suspected lower GI cancer...
# 31  The number of urgent suspected lung cancer ref...
# 32  The number of urgent suspected skin cancer ref...
#
#                                             Rationale  \
# 0                                                 NaN
# 1   Deprivation covers a broad range of issues and...
# 2   This indicator gives the total number of new c...
# 3   Breast screening supports early detection of c...
# 4   Cervical screening supports detection of cell ...
# 5   Cervical screening supports detection of cell ...
# 6   Bowel cancer screening supports early detectio...
# 7   Urgent suspected cancer referrals are a manage...
# 8   Urgent suspected cancer referrals are a manage...
# 9   Urgent suspected cancer referrals are a manage...
# 10  Cancer is a clinical priority in all four coun...
# 11  Breast screening supports early detection of c...
# 12  Breast screening supports early detection of c...
# 13  Bowel cancer screening supports early detectio...
# 14  Colonoscopies can be performed for a number of...
# 15  Sigmoidoscopies can be performed for a number ...
# 16  Endoscopies of the upper gastrointestinal (upp...
# 17  Emergency admissions may result from a number ...
# 18  Emergency presentation is linked to lower shor...
# 19  Emergency presentation is linked to lower shor...
# 20  Urgent suspected cancer referrals are a manage...
# 21  Urgent suspected cancer referrals are a manage...
# 22  Urgent suspected cancer referrals are a manage...
# 23  This indicator shows the proportion of new can...
# 24  Urgent suspected cancer referrals are a manage...
# 25  Urgent suspected cancer referrals are a manage...
# 26  Urgent suspected cancer referrals are a manage...
# 27  Urgent suspected cancer referrals are a manage...
# 28  Urgent suspected cancer referrals are a manage...
# 29  Urgent suspected cancer referrals are a manage...
# 30  Urgent suspected cancer referrals are a manage...
# 31  Urgent suspected cancer referrals are a manage...
# 32  Urgent suspected cancer referrals are a manage...
#
#                                           Data source  \
# 0                                         NHS England
# 1   English indices of deprivation 2019, Ministry ...
# 2   NHS England, National Disease Registration Ser...
# 3             NHS England, Breast Screening Programme
# 4          NHS England, Cervical Screening Programme.
# 5           NHS England, Cervical Screening Programme
# 6      NHS England, Bowel Cancer Screening Programme.
# 7   NHS England, National Disease Registration Ser...
# 8   NHS England, National Disease Registration Ser...
# 9   NHS England, National Disease Registration Ser...
# 10  Quality and Outcomes Framework (QOF), NHS England
# 11           NHS England, Breast Screening Programme.
# 12           NHS England, Breast Screening Programme.
# 13      NHS England, Bowel Cancer Screening Programme
# 14  NHS England, National Disease Registration Ser...
# 15  NHS England, National Disease Registration Ser...
# 16  NHS England, National Disease Registration Ser...
# 17  NHS England, National Disease Registration Ser...
# 18  NHS England, National Disease Registration Ser...
# 19  NHS England, National Disease Registration Ser...
# 20  NHS England, National Disease Registration Ser...
# 21  NHS England, National Disease Registration Ser...
# 22  NHS England, National Disease Registration Ser...
# 23  NHS England, National Disease Registration Ser...
# 24  NHS England, National Disease Registration Ser...
# 25  NHS England, National Disease Registration Ser...
# 26  NHS England, National Disease Registration Ser...
# 27  NHS England, National Disease Registration Ser...
# 28  NHS England, National Disease Registration Ser...
# 29  NHS England, National Disease Registration Ser...
# 30  NHS England, National Disease Registration Ser...
# 31  NHS England, National Disease Registration Ser...
# 32  NHS England, National Disease Registration Ser...
#
#                                      Indicator source  \
# 0   Data are extracted each month as a snapshot in...
# 1   For LSOA deprivation scores:  https://www.gov....
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  For the current year:  https://digital.nhs.uk/...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
#
#                                           Methodology  \
# 0   number of patients (in the specified age group...
# 1   For GP deprivation scores, the population weig...
# 2   All reportable malignant cancers, excluding no...
# 3   The data were taken from the National Health A...
# 4   Data was taken from National Health Applicatio...
# 5   Data was taken from National Health Applicatio...
# 6   Data was taken from National Health Applicatio...
# 7   Referrals are assigned to a practice based on ...
# 8   Referrals are assigned to a practice based on ...
# 9   Referrals are assigned to a practice based on ...
# 10                        numerator/denominator * 100
# 11  Data was taken from National Health Applicatio...
# 12  Data was taken from National Health Applicatio...
# 13  Data was taken from National Health Applicatio...
# 14  The number of day-case or in-patient procedure...
# 15  The number of day-case or in-patient procedure...
# 16  The number of day-case or in-patient procedure...
# 17  The number of inpatient or day-case emergency ...
# 18  Each person with a HES admitted patient care (...
# 19  Each person with a HES admitted patient care (...
# 20  Referrals are assigned to a practice based on ...
# 21  Referrals are assigned to a practice based on ...
# 22  Referrals are assigned to a practice based on ...
# 23  Referrals are assigned to a practice based on ...
# 24  Referrals are assigned to a practice based on ...
# 25  Referrals are assigned to a practice based on ...
# 26  Referrals are assigned to a practice based on ...
# 27  Referrals are assigned to a practice based on ...
# 28  Referrals are assigned to a practice based on ...
# 29  Referrals are assigned to a practice based on ...
# 30  Referrals are assigned to a practice based on ...
# 31  Referrals are assigned to a practice based on ...
# 32  Referrals are assigned to a practice based on ...
#
#     Standard population/values  Confidence interval details  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
# 5                          NaN                          NaN
# 6                          NaN                          NaN
# 7                          NaN                          NaN
# 8                          NaN                          NaN
# 9                          NaN                          NaN
# 10                         NaN                          NaN
# 11                         NaN                          NaN
# 12                         NaN                          NaN
# 13                         NaN                          NaN
# 14                         NaN                          NaN
# 15                         NaN                          NaN
# 16                         NaN                          NaN
# 17                         NaN                          NaN
# 18                         NaN                          NaN
# 19                         NaN                          NaN
# 20                         NaN                          NaN
# 21                         NaN                          NaN
# 22                         NaN                          NaN
# 23                         NaN                          NaN
# 24                         NaN                          NaN
# 25                         NaN                          NaN
# 26                         NaN                          NaN
# 27                         NaN                          NaN
# 28                         NaN                          NaN
# 29                         NaN                          NaN
# 30                         NaN                          NaN
# 31                         NaN                          NaN
# 32                         NaN                          NaN
#
#                                   Source of numerator  ... Indicator Content  \
# 0   NHS England (NHSE), Patients registered at a G...  ...               NaN
# 1                                                 NaN  ...               NaN
# 2   NHS England (NHSE), National Disease Registrat...  ...               NaN
# 3   NHS England (NHSE), Breast Screening Programme...  ...               NaN
# 4   NHS England (NHSE), Cervical Screening Program...  ...               NaN
# 5   NHS England (NHSE), Cervical Screening Program...  ...               NaN
# 6   NHS England (NHSE), Bowel Cancer Screening Pro...  ...               NaN
# 7     NHS England (NHSE), Cancer Waiting Times (CWT).  ...               NaN
# 8     NHS England (NHSE), Cancer Waiting Times (CWT).  ...               NaN
# 9     NHS England (NHSE), Cancer Waiting Times (CWT).  ...               NaN
# 10  Quality and Outcomes Framework (QOF), NHS Digital  ...               NaN
# 11  NHS England (NHSE), Breast Screening Programme...  ...               NaN
# 12  NHS England (NHSE), Breast Screening Programme...  ...               NaN
# 13  NHS England (NHSE), Bowel Cancer Screening Pro...  ...               NaN
# 14  NHS England (NHSE), Hospital Episode Statistic...  ...               NaN
# 15  NHS England (NHSE), Hospital Episode Statistic...  ...               NaN
# 16  NHS England (NHSE), Hospital Episode Statistic...  ...               NaN
# 17  NHS England (NHSE), Hospital Episode Statistic...  ...               NaN
# 18  NHS England (NHSE), Hospital Episode Statistic...  ...               NaN
# 19  NHS England (NHSE), Hospital Episode Statistic...  ...               NaN
# 20    NHS England (NHSE), Cancer Waiting Times (CWT).  ...               NaN
# 21    NHS England (NHSE), Cancer Waiting Times (CWT).  ...               NaN
# 22    NHS England (NHSE), Cancer Waiting Times (CWT).  ...               NaN
# 23    NHS England (NHSE), Cancer Waiting Times (CWT).  ...               NaN
# 24    NHS England (NHSE), Cancer Waiting Times (CWT).  ...               NaN
# 25    NHS England (NHSE), Cancer Waiting Times (CWT).  ...               NaN
# 26    NHS England (NHSE), Cancer Waiting Times (CWT).  ...               NaN
# 27    NHS England (NHSE), Cancer Waiting Times (CWT).  ...               NaN
# 28    NHS England (NHSE), Cancer Waiting Times (CWT).  ...               NaN
# 29    NHS England (NHSE), Cancer Waiting Times (CWT).  ...               NaN
# 30    NHS England (NHSE), Cancer Waiting Times (CWT).  ...               NaN
# 31    NHS England (NHSE), Cancer Waiting Times (CWT).  ...               NaN
# 32    NHS England (NHSE), Cancer Waiting Times (CWT).  ...               NaN
#
#    Specific rationale          Simple Name  \
# 0                 NaN                  NaN
# 1                 NaN                  NaN
# 2                 NaN  Incidence of cancer
# 3                 NaN                  NaN
# 4                 NaN                  NaN
# 5                 NaN                  NaN
# 6                 NaN                  NaN
# 7                 NaN                  NaN
# 8                 NaN                  NaN
# 9                 NaN                  NaN
# 10                NaN    Cancer prevalence
# 11                NaN                  NaN
# 12                NaN                  NaN
# 13                NaN                  NaN
# 14                NaN                  NaN
# 15                NaN                  NaN
# 16                NaN                  NaN
# 17                NaN                  NaN
# 18                NaN                  NaN
# 19                NaN                  NaN
# 20                NaN                  NaN
# 21                NaN                  NaN
# 22                NaN                  NaN
# 23                NaN                  NaN
# 24                NaN                  NaN
# 25                NaN                  NaN
# 26                NaN                  NaN
# 27                NaN                  NaN
# 28                NaN                  NaN
# 29                NaN                  NaN
# 30                NaN                  NaN
# 31                NaN                  NaN
# 32                NaN                  NaN
#
#                                     Simple Definition  \
# 0                                                 NaN
# 1                                                 NaN
# 2   Rate of people diagnosed with any invasive can...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  Percentage of patients with cancer (excluding ...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
#
#                                    Impact of COVID-19         Unit  \
# 0                                                 NaN            %
# 1                                                 NaN          NaN
# 2                                                 NaN  per 100,000
# 3   Breast screening coverage is low for some prac...            %
# 4                                                 NaN            %
# 5                                                 NaN            %
# 6                                                 NaN            %
# 7                                                 NaN      per 100
# 8                                                 NaN            %
# 9                                                 NaN            %
# 10  For 2020/21 QOF data,  https://digital.nhs.uk/...            %
# 11  Breast screening coverage is low for some prac...            %
# 12                                                NaN            %
# 13                                                NaN            %
# 14                                                NaN  per 100,000
# 15                                                NaN  per 100,000
# 16                                                NaN  per 100,000
# 17                                                NaN  per 100,000
# 18                                                NaN  per 100,000
# 19                                                NaN  per 100,000
# 20                                                NaN  per 100,000
# 21                                                NaN      per 100
# 22                                                NaN            %
# 23                                                NaN            %
# 24                                                NaN  per 100,000
# 25                                                NaN  per 100,000
# 26                                                NaN  per 100,000
# 27                                                NaN  per 100,000
# 28                                                NaN  per 100,000
# 29                                                NaN  per 100,000
# 30                                                NaN  per 100,000
# 31                                                NaN  per 100,000
# 32                                                NaN  per 100,000
#
#                        Value type                 Year type  \
# 0                      Proportion  Financial year end point
# 1                           Score                  Calendar
# 2                      Crude rate                 Financial
# 3                      Proportion                 Financial
# 4                      Proportion                 Financial
# 5                      Proportion                 Financial
# 6                      Proportion                 Financial
# 7   Indirectly standardised ratio                 Financial
# 8                      Proportion                 Financial
# 9                      Proportion                 Financial
# 10                     Proportion                 Financial
# 11                     Proportion                 Financial
# 12                     Proportion                 Financial
# 13                     Proportion                 Financial
# 14                     Crude rate                 Financial
# 15                     Crude rate                 Financial
# 16                     Crude rate                 Financial
# 17                     Crude rate                 Financial
# 18                     Crude rate                 Financial
# 19                     Crude rate                 Financial
# 20                     Crude rate                 Financial
# 21  Indirectly standardised ratio                 Financial
# 22                     Proportion                 Financial
# 23                     Proportion                 Financial
# 24                     Crude rate                 Financial
# 25                     Crude rate                 Financial
# 26                     Crude rate                 Financial
# 27                     Crude rate                 Financial
# 28                     Crude rate                 Financial
# 29                     Crude rate                 Financial
# 30                     Crude rate                 Financial
# 31                     Crude rate                 Financial
# 32                     Crude rate                 Financial
#
#                   Polarity Date updated
# 0           Not applicable   22/05/2024
# 1        RAG - Low is good   21/03/2023
# 2   BOB - Blue orange blue   13/12/2023
# 3   BOB - Blue orange blue   28/11/2023
# 4   BOB - Blue orange blue   20/12/2023
# 5   BOB - Blue orange blue   20/12/2023
# 6   BOB - Blue orange blue   08/12/2023
# 7   BOB - Blue orange blue   17/11/2023
# 8   BOB - Blue orange blue   17/11/2023
# 9   BOB - Blue orange blue   29/01/2024
# 10  BOB - Blue orange blue   29/04/2024
# 11  BOB - Blue orange blue   28/11/2023
# 12  BOB - Blue orange blue   28/11/2023
# 13  BOB - Blue orange blue   28/11/2023
# 14  BOB - Blue orange blue   14/11/2023
# 15  BOB - Blue orange blue   14/11/2023
# 16  BOB - Blue orange blue   14/11/2023
# 17  BOB - Blue orange blue   14/11/2023
# 18  BOB - Blue orange blue   14/11/2023
# 19  BOB - Blue orange blue   14/11/2023
# 20  BOB - Blue orange blue   17/11/2023
# 21  BOB - Blue orange blue   17/11/2023
# 22  BOB - Blue orange blue   17/11/2023
# 23  BOB - Blue orange blue   29/01/2024
# 24  BOB - Blue orange blue   17/11/2023
# 25  BOB - Blue orange blue   17/11/2023
# 26  BOB - Blue orange blue   17/11/2023
# 27  BOB - Blue orange blue   17/11/2023
# 28  BOB - Blue orange blue   17/11/2023
# 29  BOB - Blue orange blue   17/11/2023
# 30  BOB - Blue orange blue   17/11/2023
# 31  BOB - Blue orange blue   17/11/2023
# 32  BOB - Blue orange blue   17/11/2023
#
# [33 rows x 32 columns]

# %%
ftp.metadata.get_area_types_as_dict(is_test=False) #pulls metadata on area codes e.g data for GPs = 7

# %%
from urllib.parse import urlencode
import pandas as pd

def get_all_data_for_indicators(indicators, area_type_id, parent_area_type_id, filter_by_area_codes, is_test):
    base_url = 'https://fingertipsws.phe.org.uk/api/'  # Replace with your actual base URL
    endpoint = 'all_data/csv/by_indicator_id'
    
    # Construct URL with proper encoding
    params = {
        'indicator_ids': ','.join(indicators),
        'child_area_type_id': area_type_id,
        'parent_area_type_id': parent_area_type_id,
        'filter_by_area_codes': filter_by_area_codes
    }
    
    # Construct the full URL
    full_url = f"{base_url}{endpoint}?{urlencode(params)}"
    
    # Fetch data
    try:
        df = pd.read_csv(full_url)
        return df
    except Exception as e:
        print(f"An error occurred: {e}")
        # Handle exception as needed

# Custom parameters
indicators = ['91355', '91357', '276', '91280', '91845', '92588', '93553', '91337']
area_type_id = 7
parent_area_type_id = 66
filter_by_area_codes = False
is_test = False

df = get_all_data_for_indicators(indicators, area_type_id, parent_area_type_id, filter_by_area_codes, is_test)
# Out:
# C:\Users\MaiaSlidel\AppData\Local\Temp\ipykernel_26992\2978097557.py:21: DtypeWarning: Columns (9,10,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(full_url)

# %%
ncl_icb_only = df[df['Parent Code'] == 'nE38000240'] #filtering data for NCL ICB only

# %%
ncl_icb_only.head()
# Out:
#       Indicator ID                              Indicator Name Parent Code  \
# 1898         91355  Number of emergency admissions with cancer  nE38000240
# 1899         91355  Number of emergency admissions with cancer  nE38000240
# 1900         91355  Number of emergency admissions with cancer  nE38000240
# 1901         91355  Number of emergency admissions with cancer  nE38000240
# 1902         91355  Number of emergency admissions with cancer  nE38000240
#
#                           Parent Name Area Code  \
# 1898  North Central London ICB - 93C     E83003
# 1899  North Central London ICB - 93C     E83005
# 1900  North Central London ICB - 93C     E83006
# 1901  North Central London ICB - 93C     E83007
# 1902  North Central London ICB - 93C     E83008
#
#                           Area Name Area Type      Sex       Age  \
# 1898    Oakleigh Road Health Centre       GPs  Persons  All ages
# 1899        Lichfield Grove Surgery       GPs  Persons  All ages
# 1900      Greenfield Medical Centre       GPs  Persons  All ages
# 1901  Squires Lane Medical Practice       GPs  Persons  All ages
# 1902     Heathfielde Medical Centre       GPs  Persons  All ages
#
#      Category Type  ... Count Denominator  \
# 1898           NaN  ...  92.0      8037.0
# 1899           NaN  ...  12.0      3651.0
# 1900           NaN  ...  34.0      6859.0
# 1901           NaN  ...  55.0      5582.0
# 1902           NaN  ...  33.0      7285.0
#
#                                          Value note  Recent Trend  \
# 1898  There is a data quality issue with this value           NaN
# 1899  There is a data quality issue with this value           NaN
# 1900  There is a data quality issue with this value           NaN
# 1901  There is a data quality issue with this value           NaN
# 1902  There is a data quality issue with this value           NaN
#
#       Compared to England value or percentiles  \
# 1898                                    Higher
# 1899                                   Similar
# 1900                                   Similar
# 1901                                    Higher
# 1902                                   Similar
#
#       Compared to ICB sub-locations value or percentiles  \
# 1898                                             Higher
# 1899                                            Similar
# 1900                                            Similar
# 1901                                             Higher
# 1902                                            Similar
#
#       Time period Sortable  New data  Compared to goal Time period range
# 1898              20090000       NaN               NaN                1y
# 1899              20090000       NaN               NaN                1y
# 1900              20090000       NaN               NaN                1y
# 1901              20090000       NaN               NaN                1y
# 1902              20090000       NaN               NaN                1y
#
# [5 rows x 27 columns]

# %%
#removing unwanted columns

usable = ncl_icb_only[['Indicator ID',
'Indicator Name',
'Area Code',
'Area Name',
'Value',
'Upper CI 99.8 limit',
'Count',
'Denominator',
'Time period Sortable',
'Time period range'
]]

usable.head()
# Out:
#       Indicator ID                              Indicator Name Area Code  \
# 1898         91355  Number of emergency admissions with cancer    E83003
# 1899         91355  Number of emergency admissions with cancer    E83005
# 1900         91355  Number of emergency admissions with cancer    E83006
# 1901         91355  Number of emergency admissions with cancer    E83007
# 1902         91355  Number of emergency admissions with cancer    E83008
#
#                           Area Name        Value  Upper CI 99.8 limit  Count  \
# 1898    Oakleigh Road Health Centre  1144.705736          1563.888648   92.0
# 1899        Lichfield Grove Surgery   328.677075           741.740875   12.0
# 1900      Greenfield Medical Centre   495.699081           819.240586   34.0
# 1901  Squires Lane Medical Practice   985.309925          1469.433009   55.0
# 1902     Heathfielde Medical Centre   452.985587           754.006745   33.0
#
#       Denominator  Time period Sortable Time period range
# 1898       8037.0              20090000                1y
# 1899       3651.0              20090000                1y
# 1900       6859.0              20090000                1y
# 1901       5582.0              20090000                1y
# 1902       7285.0              20090000                1y

# %%
#grouping by indicator name & GP code, then getting maximum date available for each - filters the data to get latest data for each indicator only
idx=usable.groupby(['Indicator Name','Area Code'])['Time period Sortable'].idxmax()
#m=max(usable['Time period Sortable'])

max_rows = usable.loc[idx]

# %%
#transforming dataframe into a csv file
max_rows.to_csv('Fingertips_Data.csv',index=False)

# %% [markdown]
# ## Retrieving Social Prescribing Data
#
# Data pre-downloaded and saved to raw data folder - SP data is emailed to us by NCL ICB and is not available in Fingertips

# %%
sp = pd.read_csv('Data/Raw/ICB/Cancer_Safety_Netting_Social_Prescribing_FIT/Social Prescribing/Social prescriber referrals made in the last 12 months.csv')

# %%
sp.head(10) #having a look at the raw data
# Out:
#   Social prescriber referrals made in the last 12 months  \
# 0                                                NaN
# 1                                        Description
# 2                                  Parent Population
# 3                                             Author
# 4                                           Last Run
# 5                                                NaN
# 6                                       Organisation
# 7                          THE MUSWELL HILL PRACTICE
# 8                            Highgate Group Practice
# 9                              THE BEAUMONT PRACTICE
#
#                               Unnamed: 1        Unnamed: 2     Unnamed: 3  \
# 0                                    NaN               NaN            NaN
# 1  No of referrals, offered and declined               NaN            NaN
# 2  Currently registered regular patients               NaN            NaN
# 3                NAZIMUDDIN, Nezila (Ms)               NaN  Date Modified
# 4                      02-Jul-2024 11:05               NaN  Relative Date
# 5                                    NaN               NaN            NaN
# 6                                    CDB  Population Count         Parent
# 7                                 F85063               130          16777
# 8                                 F85014               269          16883
# 9                                 F83671                30           3269
#
#     Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          NaN        NaN        NaN        NaN        NaN
# 1          NaN        NaN        NaN        NaN        NaN
# 2          NaN        NaN        NaN        NaN        NaN
# 3  30-Sep-2022        NaN        NaN        NaN        NaN
# 4  01-Jul-2024        NaN        NaN        NaN        NaN
# 5          NaN        NaN        NaN        NaN        NaN
# 6            %      Males    Females   Excluded     Status
# 7           1%         46         84      16647  Completed
# 8           2%         89        180      16614  Completed
# 9           1%         14         16       3239  Completed

# %%
#promoting 6th row as header
new_header = sp.iloc[6]
sp2 = sp[1:]

# %%
sp2.columns = new_header
sp2.head(10)
# Out:
# 6                Organisation                                    CDB  \
# 1                 Description  No of referrals, offered and declined
# 2           Parent Population  Currently registered regular patients
# 3                      Author                NAZIMUDDIN, Nezila (Ms)
# 4                    Last Run                      02-Jul-2024 11:05
# 5                         NaN                                    NaN
# 6                Organisation                                    CDB
# 7   THE MUSWELL HILL PRACTICE                                 F85063
# 8     Highgate Group Practice                                 F85014
# 9       THE BEAUMONT PRACTICE                                 F83671
# 10  EAST BARNET HEALTH CENTRE                                 E83613
#
# 6   Population Count         Parent            %  Males  Females  Excluded  \
# 1                NaN            NaN          NaN    NaN      NaN       NaN
# 2                NaN            NaN          NaN    NaN      NaN       NaN
# 3                NaN  Date Modified  30-Sep-2022    NaN      NaN       NaN
# 4                NaN  Relative Date  01-Jul-2024    NaN      NaN       NaN
# 5                NaN            NaN          NaN    NaN      NaN       NaN
# 6   Population Count         Parent            %  Males  Females  Excluded
# 7                130          16777           1%     46       84     16647
# 8                269          16883           2%     89      180     16614
# 9                 30           3269           1%     14       16      3239
# 10               137          11241           1%     53       84     11104
#
# 6      Status
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6      Status
# 7   Completed
# 8   Completed
# 9   Completed
# 10  Completed

# %%
#dropping the first few rows
sp3 = sp2.drop([1,2,3,4,5,6], axis='index')
sp3.head(10)
# Out:
# 6                      Organisation     CDB Population Count Parent   % Males  \
# 7         THE MUSWELL HILL PRACTICE  F85063              130  16777  1%    46
# 8           Highgate Group Practice  F85014              269  16883  2%    89
# 9             THE BEAUMONT PRACTICE  F83671               30   3269  1%    14
# 10        EAST BARNET HEALTH CENTRE  E83613              137  11241  1%    53
# 11      Bounds Green Group Practice  F85066              205  19027  1%    71
# 12  BELSIZE PRIORY MEDICAL PRACTICE  F83658              102   5591  2%    53
# 13     EAST FINCHLEY MEDICAL CENTRE  E83050              144   7524  2%    57
# 14     The Crouch Hall Road Surgery  F85069              132   8391  2%    58
# 15     Temple Fortune Medical Group  E83622              129   9388  1%    38
# 16       Ravenscroft Medical Centre  E83039               85   5940  1%    37
#
# 6  Females Excluded     Status
# 7       84    16647  Completed
# 8      180    16614  Completed
# 9       16     3239  Completed
# 10      84    11104  Completed
# 11     134    18822  Completed
# 12      49     5489  Completed
# 13      87     7380  Completed
# 14      74     8259  Completed
# 15      91     9259  Completed
# 16      48     5855  Completed

# %%
#dropping the total row
sp4 = sp3.drop(sp3[sp3['Organisation'] == 'Total'].index)

# %%
#creating new df with only required columns
sp5 = sp4[['Organisation', 'CDB', 'Population Count']]

# %%
#renaming the columns to match the FT data, prepping to join them vertically
sp5.rename(columns={'Organisation':'Area Name','CDB':'Area Code','Population Count':'Value'}, inplace=True)
# Out:
# C:\Users\MaiaSlidel\AppData\Local\Temp\ipykernel_26992\3101081217.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sp5.rename(columns={'Organisation':'Area Name','CDB':'Area Code','Population Count':'Value'}, inplace=True)

# %%
#checking if the columns in SP data are in FT, if not then populate them with NA (reason for this is that both DFs need to be the same width to perform the vertical join)
for column in max_rows.columns:
    if column not in sp5.columns:
        sp5[column] = pd.NA

sp5 = sp5[max_rows.columns]
# Out:
# C:\Users\MaiaSlidel\AppData\Local\Temp\ipykernel_26992\3889559910.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sp5[column] = pd.NA
# C:\Users\MaiaSlidel\AppData\Local\Temp\ipykernel_26992\3889559910.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sp5[column] = pd.NA
# C:\Users\MaiaSlidel\AppData\Local\Temp\ipykernel_26992\3889559910.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sp5[column] = pd.NA
# C:\Users\MaiaSlidel\AppData\Local\Temp\ipykernel_26992\3889559910.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sp5[column] = pd.NA
# C:\Users\MaiaSlidel\AppData\Local\Temp\ipykernel_26992\3889559910.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sp5[column] = pd.NA

# %%
#setting indicator name for SP data
sp5['Indicator Name'] = 'No. of Social Prescribing referrals made within the last 12 months'

# %%
#extracts date from raw SP file and populates a date column
from datetime import datetime
relative_date_str = sp2.loc[sp2['Parent'] == 'Relative Date', '%'].values[0]
print(f"Relative Date: {relative_date}")
# Out:
# Relative Date: 01-Jul-2024

# %%
relative_date = datetime.strptime(relative_date_str, '%d-%b-%Y')
year = relative_date.strftime('%Y')
print(f"Year extracted: {year}")
# Out:
# Year extracted: 2024

# %%
sp5['Time period Sortable'] = year + '0000' #making SP extracted date match format in FT data

# %%
#commencing the merge!!!
merged = pd.concat([max_rows, sp5], ignore_index = True)
merged.head(10)
# Out:
# C:\Users\MaiaSlidel\AppData\Local\Temp\ipykernel_26992\2919347274.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   merged = pd.concat([max_rows, sp5], ignore_index = True)
#   Indicator ID                     Indicator Name Area Code  \
# 0          276  Cancer: QOF prevalence (all ages)    E83003
# 1          276  Cancer: QOF prevalence (all ages)    E83005
# 2          276  Cancer: QOF prevalence (all ages)    E83006
# 3          276  Cancer: QOF prevalence (all ages)    E83007
# 4          276  Cancer: QOF prevalence (all ages)    E83008
# 5          276  Cancer: QOF prevalence (all ages)    E83009
# 6          276  Cancer: QOF prevalence (all ages)    E83010
# 7          276  Cancer: QOF prevalence (all ages)    E83011
# 8          276  Cancer: QOF prevalence (all ages)    E83012
# 9          276  Cancer: QOF prevalence (all ages)    E83013
#
#                         Area Name    Value  Upper CI 99.8 limit  Count  \
# 0     Oakleigh Road Health Centre  4.09853              4.77773  386.0
# 1         Lichfield Grove Surgery  2.43454              3.09697  159.0
# 2       Greenfield Medical Centre  3.26463              3.97469  236.0
# 3   Squires Lane Medical Practice   3.1946              4.01416  175.0
# 4      Heathfielde Medical Centre  3.14112              3.77145  274.0
# 5                    Phgh Doctors  4.67091              5.29632  572.0
# 6          The Speedwell Practice  4.09118              4.70008  472.0
# 7  The Everglade Medical Practice  1.65408              2.07138  184.0
# 8     The Old Court House Surgery  4.58897              5.31629  417.0
# 9          Cornwall House Surgery   3.2872              4.09248  190.0
#
#    Denominator Time period Sortable Time period range
# 0       9418.0             20220000                1y
# 1       6531.0             20220000                1y
# 2       7229.0             20220000                1y
# 3       5478.0             20220000                1y
# 4       8723.0             20220000                1y
# 5      12246.0             20220000                1y
# 6      11537.0             20220000                1y
# 7      11124.0             20220000                1y
# 8       9087.0             20220000                1y
# 9       5780.0             20220000                1y

# %%
merged['Indicator Name'].unique() #test to see unique indicator names
# Out:
# array(['Cancer: QOF prevalence (all ages)',
#        'Deprivation score (IMD 2019)',
#        'New cancer cases (Crude incidence rate)',
#        'Number of emergency admissions with cancer',
#        'Number of other (non-emergency) presentations',
#        'Obesity: QOF prevalence (18+ yrs)',
#        'Smoking: QOF prevalence (15+ yrs)',
#        'Urgent suspected cancer referrals resulting in a diagnosis of cancer (Conversion rate: as % of all USC referrals)',
#        'No. of Social Prescribing referrals made within the last 12 months'],
#       dtype=object)

# %%
#saving to prod folder
file_name = 'PCN Population Health FT_ICB.csv'
full_path  = 'Data/Production' + '/' + file_name
merged.to_csv(full_path, index=False)
print('saved file to production folder!')
# Out:
# saved file to production folder!

# %%
check = merged[merged['Indicator Name'] =='No. of Social Prescribing referrals made within the last 12 months'] 
check.head(10)
#final test to check the merge for social prescribing data
# Out:
#      Indicator ID                                     Indicator Name  \
# 1416         <NA>  No. of Social Prescribing referrals made withi...
# 1417         <NA>  No. of Social Prescribing referrals made withi...
# 1418         <NA>  No. of Social Prescribing referrals made withi...
# 1419         <NA>  No. of Social Prescribing referrals made withi...
# 1420         <NA>  No. of Social Prescribing referrals made withi...
# 1421         <NA>  No. of Social Prescribing referrals made withi...
# 1422         <NA>  No. of Social Prescribing referrals made withi...
# 1423         <NA>  No. of Social Prescribing referrals made withi...
# 1424         <NA>  No. of Social Prescribing referrals made withi...
# 1425         <NA>  No. of Social Prescribing referrals made withi...
#
#      Area Code                        Area Name Value  Upper CI 99.8 limit  \
# 1416    F85063        THE MUSWELL HILL PRACTICE   130                  NaN
# 1417    F85014          Highgate Group Practice   269                  NaN
# 1418    F83671            THE BEAUMONT PRACTICE    30                  NaN
# 1419    E83613        EAST BARNET HEALTH CENTRE   137                  NaN
# 1420    F85066      Bounds Green Group Practice   205                  NaN
# 1421    F83658  BELSIZE PRIORY MEDICAL PRACTICE   102                  NaN
# 1422    E83050     EAST FINCHLEY MEDICAL CENTRE   144                  NaN
# 1423    F85069     The Crouch Hall Road Surgery   132                  NaN
# 1424    E83622     Temple Fortune Medical Group   129                  NaN
# 1425    E83039       Ravenscroft Medical Centre    85                  NaN
#
#       Count  Denominator Time period Sortable Time period range
# 1416    NaN          NaN             20240000               NaN
# 1417    NaN          NaN             20240000               NaN
# 1418    NaN          NaN             20240000               NaN
# 1419    NaN          NaN             20240000               NaN
# 1420    NaN          NaN             20240000               NaN
# 1421    NaN          NaN             20240000               NaN
# 1422    NaN          NaN             20240000               NaN
# 1423    NaN          NaN             20240000               NaN
# 1424    NaN          NaN             20240000               NaN
# 1425    NaN          NaN             20240000               NaN
